# %%
import pandas as pd

# %%
data = pd.read_json("/home/fuhr/Documents/recipes_raw/recipes_raw_nosource_ar.json", orient="records")
data.append(pd.read_json("/home/fuhr/Documents/recipes_raw/recipes_raw_nosource_epi.json", orient="records"))
data.append(pd.read_json("/home/fuhr/Documents/recipes_raw/recipes_raw_nosource_fn.json", orient="records"))
# Out:
# /home/fuhr/.local/lib/python3.6/site-packages/pandas/core/frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
#                                 ../AFIrLizRK7C5isREQ0hUdXoNXTpS  \
# title                                  Creamy Deviled Egg Salad
# ingredients   [2 1/2 cups creamy salad dressing (such as Mir...
# instructions  Mix creamy salad dressing, mustard, sugar, and...
# picture_link                    C0dLeqJsHiETBZCxg4uw0aqGvrSjRea
# instructions                                                NaN
# ingredients                                                 NaN
# title                                                       NaN
# picture_link                                                NaN
#
# ...

# %%
trans = data.transpose()

# %%
trans['title']
# Out:
# rmK12Uau.ntP510KeImX506H6Mr6jTu         Slow Cooker Chicken and Dumplings
# 5ZpZE8hSVdPk2ZXo1mZTyoPWJRSCPSm             Awesome Slow Cooker Pot Roast
# clyYQv.CplpwJtjNaFGhx0VilNYqRxu                      Brown Sugar Meatloaf
# BmqFAmCrDHiKNwX.IQzb0U/v0mLlxFu               Best Chocolate Chip Cookies
# N.jCksRjB4MFwbgPFQU8Kg.yF.XCtOi         Homemade Mac and Cheese Casserole
#                                                     ...
# gehEOcDPtU3SmNSXrwWwWD4ulPpUdMO                   Thai-Indian Veggie Soup
# VRAsyF.1xMBYqAVKX1biyIORH6N6qzy    Coconut Milk-Free Panang Curry Chicken
# Lf8/u.0k2029QMSQFrHS4gRsvKOQFUG                         Cooked Cold Salad
# ay.AqX/9ysBtWHcnHoDeGAyJ5Orla8e                  Easy Eggnog Creme Brulee
# 2Q3Zpfgt/PUwn1YABjJ5A9T3ZW8xwVa              Super Power Stovetop Granola
# Name: title, Length: 39802, dtype: object

# %%
data_csv = data.to_csv()

# %%
with open("recipes.csv","w") as csv_file:
    csv_file.write(data_csv)

# %%
data = pd.read_csv("./recipes.csv")

# %%
print(data.shape)
data_transposed = data.transpose()
print(data_transposed.shape)
# Out:
# (4, 39803)
# (39803, 4)

# %%
print(data_transposed.keys())
# Out:
# RangeIndex(start=0, stop=4, step=1)
